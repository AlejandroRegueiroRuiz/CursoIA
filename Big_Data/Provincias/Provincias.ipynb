# %%
import pandas as pd
import os

ruta = "./csvs/"
provList=["Coruna","Lugo","Ourense","Pontevedra"]
resultado_df = pd.DataFrame()

resultado_df = pd.concat([pd.read_csv(f"{ruta}{prov}.csv") for prov in provList], ignore_index=True)

#resultado_df
pd.DataFrame([resultado_df.Concello, resultado_df.Provincia])

#resultado_df.to_csv('ProvJuntas.csv', index = False)
# Out:
#                0         1         2         3         4         5     \
# Concello   Abegondo      Ames      Ames      Ares   Arteixo  A Coruña
# Provincia  A Coruña  A Coruña  A Coruña  A Coruña  A Coruña  A Coruña
#
#                6         7         8         9     ...        1629     1630  \
# Concello    Arteixo     Arzúa     Arzúa  Bergondo  ...  Monterroso  Begonte
# Provincia  A Coruña  A Coruña  A Coruña  A Coruña  ...        Lugo     Lugo
#
#                      1631      1632  1633    1634  1635     1636  1637  1638
# Concello   Outeiro de Rei  Chantada  Lugo  Burela  Lugo  Begonte  Lugo  Lugo
# Provincia            Lugo      Lugo  Lugo    Lugo  Lugo     Lugo  Lugo  Lugo
#
# [2 rows x 1639 columns]
