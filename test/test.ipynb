# %%
import pandas as pd

# %%
Pp15_16 = pd.read_json('../meteo/Pont2015-2016.json')

# %%
Pp15_16.to_csv('../meteo/Pont2015-2016.csv')
# Out:
#              Estación                       Variable Unidad  \
# 0         Monte Aloia         Horas de frío ( <=7ºC)      h
# 1         Monte Aloia  Temperatura de orballo a 1.5m     ºC
# 2         Monte Aloia      Temperatura máxima a 1.5m     ºC
# 3         Monte Aloia       Temperatura media a 1.5m     ºC
# 4         Monte Aloia      Temperatura mínima a 1.5m     ºC
# ...               ...                            ...    ...
# 77867  Ponte Caldelas  Temperatura de orballo a 1.5m     ºC
# 77868  Ponte Caldelas      Temperatura máxima a 1.5m     ºC
# 77869  Ponte Caldelas       Temperatura media a 0.1m     ºC
# 77870  Ponte Caldelas       Temperatura media a 1.5m     ºC
# 77871  Ponte Caldelas      Temperatura mínima a 1.5m     ºC
#
#                     Código       Fecha  Valor  Código de validación
# 0      HFRIO_RECUENTO_1.5m  28/03/2015   0.00                     1
# 1              TO_AVG_1.5m  28/03/2015   8.45                     1
# ...
